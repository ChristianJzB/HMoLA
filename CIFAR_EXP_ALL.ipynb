# %%
import os
import torch
import torchvision
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from laplace import Laplace
import pandas as pd

from torch.optim.swa_utils import AveragedModel, SWALR


from CIFAR_Data import get_cifar10_loaders
from CIFAR_MODEL import FixupWideResNet


import torch.utils.data as data_utils
import torchvision.transforms.functional as TF
from torchvision import transforms, datasets

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        X, y = X.to(device), y.to(device)
        #
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")



def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
datapath = os.path.join(os.getcwd(),"CIFAR-10-C","CIFAR-10-C")
corruptions = os.listdir(datapath)
corruptions.remove('desktop.ini')

# %%
## Load corrupted images on memory
corrupted_images = {}

for corruption in corruptions:
  if 'labels' in corruption:
    labels = np.load(os.path.join(datapath,corruption))
    continue

  corruption_type = corruption.split('.')[0]

  imgs = np.load(os.path.join(datapath,corruption))
  corrupted_images[corruption_type] = imgs

# %%
# corrupted_images_severity = {}
# corrupted_images_labels = {}


# for severity in range(0,5):

#     ax = np.concatenate([corrupted_images[corruption][severity*10000:(severity+1)*10000] for corruption in corrupted_images.keys()],axis=0)

#     corrupted_images_severity[str(severity+1)] = ax

#     ax = np.concatenate([labels[severity*10000:(severity+1)*10000] for _ in range(0,19)],axis=0)

#     corrupted_images_labels[str(severity+1)] = ax

# %%
# cor = ['snow', 'gaussian_noise', 'motion_blur']
# np_x = { your_key: corrupted_images[your_key] for your_key in cor }

cor = "gaussian_noise"
np_x = corrupted_images[cor]

# %%
corrupted_images_severity = {}
corrupted_images_labels = {}


for severity in range(0,5):

    ax = np_x[severity*10000:(severity+1)*10000]

    corrupted_images_severity[str(severity+1)] = ax

    ax = labels[severity*10000:(severity+1)*10000]

    corrupted_images_labels[str(severity+1)] = ax

# %%
# corrupted_images_severity = {}
# corrupted_images_labels = {}


# for severity in range(0,5):

#     ax = np_x['snow'][severity*10000:(severity+1)*10000]

#     for k in ['gaussian_noise', 'motion_blur']:
#         ax = np.concatenate((ax,np_x[k][severity*10000:(severity+1)*10000]),axis=0)

#     corrupted_images_severity[str(severity+1)] = ax

#     ax = labels[severity*10000:(severity+1)*10000]

#     for k in ['gaussian_noise', 'motion_blur']:
#         ax = np.concatenate((ax,ax),axis=0)

#     corrupted_images_labels[str(severity+1)] = ax

# %%
class DatafeedImage(torch.utils.data.Dataset):
    def __init__(self, x_train, y_train, transform=None):
        self.x_train = x_train
        self.y_train = y_train
        self.transform = transform

    def __getitem__(self, index):
        img = self.x_train[index]
        #img = Image.fromarray(img)
        if self.transform is not None:
            img = self.transform(img)
        return img, self.y_train[index]

    def __len__(self):
        return len(self.x_train)

# %%
def load_corrupted_cifar10(severity,data,labels, batch_size=256,workers=1):
    """ load corrupted CIFAR10 dataset """

    # x_file = data_dir + '/CIFAR-10-C/CIFAR10_c%d.npy' % severity
    # np_x = np.load(x_file)
    # y_file = data_dir + '/CIFAR-10-C/CIFAR10_c_labels.npy'
    # np_y = np.load(y_file).astype(np.int64)

    np_y = labels[severity].astype(np.int64)
    np_x = data[severity]

    transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
    ])
    
    dataset = DatafeedImage(np_x, np_y, transform)
    #dataset = data_utils.Subset(dataset, torch.randint(len(dataset), (10000,)))

    loader = torch.utils.data.DataLoader(dataset,batch_size=batch_size)

    return loader

# %%
def get_brier_score(probs, targets):
    targets = F.one_hot(targets, num_classes=probs.shape[1])
    return torch.mean(torch.sum((probs - targets)**2, axis=1)).item()

# %%
def get_calib(pys, y_true, M=100):
    pys, y_true = pys.cpu().numpy(), y_true.cpu().numpy()
    # Put the confidence into M bins
    _, bins = np.histogram(pys, M, range=(0, 1))

    labels = pys.argmax(1)
    confs = np.max(pys, axis=1)
    conf_idxs = np.digitize(confs, bins)

    # Accuracy and avg. confidence per bin
    accs_bin = []
    confs_bin = []
    nitems_bin = []

    for i in range(M):
        labels_i = labels[conf_idxs == i]
        y_true_i = y_true[conf_idxs == i]
        confs_i = confs[conf_idxs == i]

        acc = np.nan_to_num(np.mean(labels_i == y_true_i), 0)
        conf = np.nan_to_num(np.mean(confs_i), 0)

        accs_bin.append(acc)
        confs_bin.append(conf)
        nitems_bin.append(len(labels_i))

    accs_bin, confs_bin = np.array(accs_bin), np.array(confs_bin)
    nitems_bin = np.array(nitems_bin)

    ECE = np.average(np.abs(confs_bin-accs_bin), weights=nitems_bin/nitems_bin.sum())
    MCE = np.max(np.abs(accs_bin - confs_bin))

    return ECE, MCE

# %%
@torch.no_grad()
def mixture_model_pred(components, x, mixture_weights,MAP=False):

    out = 0.  # out will be a tensor

    for model, pi in zip(components, mixture_weights):
        if MAP:
            out_prob = torch.softmax(model(X),dim=1)
        else:    
            out_prob = model(x)
        
        out += pi * out_prob
        
    return out

# %%
n_models = 3
ECE_ = {"Diag":{},"Kron":{},"MAP":{},"SWA":{},"HMoLA":{}}
NLL_ = {"Diag":{},"Kron":{},"MAP":{},"SWA":{},"HMoLA":{}}
BRI_ = {"Diag":{},"Kron":{},"MAP":{},"SWA":{},"HMoLA":{}}

loss_fn = torch.nn.CrossEntropyLoss()

pi = torch.ones(n_models, device=device) / n_models

# %%
### SWAG

learning_rate = 1e-6
epochs = 15
n_models = 3

# %%
file_models = [os.path.join(os.getcwd(),"CIFAR_m"+str(n+1)+".pth") for n in range(n_models)]

models = [FixupWideResNet(16, 4, 10, dropRate=0.3).to(device) for _ in range(n_models)]

for file, model in zip(file_models,models):
    model.load_state_dict(torch.load(file))
    model.eval()

SWAG_models = []

train_dataloader, test_dataloader = get_cifar10_loaders()

loss_fn = torch.nn.CrossEntropyLoss()

for n,model in enumerate(models):

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    swa_model = AveragedModel(model)
    #scheduler = CosineAnnealingLR(optimizer, T_max=100)
    #swa_start = int((epochs)*(.75))
    swa_start = 0
    swa_scheduler = SWALR(optimizer, swa_lr=0.8e-6)

    for t in range(epochs):
        print(f"Epoch {t+1}\n-------------------------------")
        train_loop(train_dataloader, model, loss_fn, optimizer)

        if epochs > swa_start:
            swa_model.update_parameters(model)
            swa_scheduler.step()

        test_loop(test_dataloader, model, loss_fn)

    print(f"Training routine finished for model: {n+1}")


    torch.optim.swa_utils.update_bn(train_dataloader, swa_model)

    SWAG_models.append(swa_model)
# Out:
# Epoch 1
# -------------------------------
# loss: 0.042648  [    0/50000]
# loss: 0.140148  [12800/50000]
# loss: 0.060127  [25600/50000]
# loss: 0.076457  [38400/50000]
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.371665
#
# Epoch 2
# -------------------------------
# loss: 0.063213  [    0/50000]
# loss: 0.025320  [12800/50000]
# loss: 0.059573  [25600/50000]
# loss: 0.062309  [38400/50000]
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.371590
#
# Epoch 3
# -------------------------------
# loss: 0.071571  [    0/50000]
# loss: 0.055749  [12800/50000]
# loss: 0.096954  [25600/50000]
# loss: 0.037512  [38400/50000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.381941
#
# Epoch 4
# -------------------------------
# loss: 0.036591  [    0/50000]
# loss: 0.075538  [12800/50000]
# loss: 0.059768  [25600/50000]
# loss: 0.068440  [38400/50000]
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.372878
#
# Epoch 5
# -------------------------------
# loss: 0.067396  [    0/50000]
# loss: 0.089770  [12800/50000]
# loss: 0.023245  [25600/50000]
# loss: 0.041666  [38400/50000]
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.362622
#
# Epoch 6
# -------------------------------
# loss: 0.081830  [    0/50000]
# loss: 0.067419  [12800/50000]
# loss: 0.063770  [25600/50000]
# loss: 0.050175  [38400/50000]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.362727
#
# Epoch 7
# -------------------------------
# loss: 0.062121  [    0/50000]
# loss: 0.035577  [12800/50000]
# loss: 0.028494  [25600/50000]
# loss: 0.032297  [38400/50000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.366084
#
# Epoch 8
# -------------------------------
# loss: 0.039301  [    0/50000]
# loss: 0.089903  [12800/50000]
# loss: 0.065231  [25600/50000]
# loss: 0.035049  [38400/50000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.364960
#
# Epoch 9
# -------------------------------
# loss: 0.049542  [    0/50000]
# loss: 0.052581  [12800/50000]
# loss: 0.055088  [25600/50000]
# loss: 0.039502  [38400/50000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.365921
#
# Epoch 10
# -------------------------------
# loss: 0.048293  [    0/50000]
# loss: 0.039945  [12800/50000]
# loss: 0.128759  [25600/50000]
# loss: 0.042626  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.371000
#
# Epoch 11
# -------------------------------
# loss: 0.042062  [    0/50000]
# loss: 0.048987  [12800/50000]
# loss: 0.043133  [25600/50000]
# loss: 0.023189  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.368338
#
# Epoch 12
# -------------------------------
# loss: 0.017275  [    0/50000]
# loss: 0.077652  [12800/50000]
# loss: 0.049792  [25600/50000]
# loss: 0.036645  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.365641
#
# Epoch 13
# -------------------------------
# loss: 0.017648  [    0/50000]
# loss: 0.093384  [12800/50000]
# loss: 0.039677  [25600/50000]
# loss: 0.060429  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.367499
#
# Epoch 14
# -------------------------------
# loss: 0.030334  [    0/50000]
# loss: 0.051956  [12800/50000]
# loss: 0.032475  [25600/50000]
# loss: 0.036651  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.370967
#
# Epoch 15
# -------------------------------
# loss: 0.027941  [    0/50000]
# loss: 0.046558  [12800/50000]
# loss: 0.020810  [25600/50000]
# loss: 0.034489  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.377210
#
# Training routine finished for model: 1
# Epoch 1
# -------------------------------
# loss: 0.045096  [    0/50000]
# loss: 0.068197  [12800/50000]
# loss: 0.055739  [25600/50000]
# loss: 0.054331  [38400/50000]
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.387431
#
# Epoch 2
# -------------------------------
# loss: 0.050061  [    0/50000]
# loss: 0.088909  [12800/50000]
# loss: 0.027300  [25600/50000]
# loss: 0.062173  [38400/50000]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.383801
#
# Epoch 3
# -------------------------------
# loss: 0.040273  [    0/50000]
# loss: 0.082907  [12800/50000]
# loss: 0.066553  [25600/50000]
# loss: 0.054313  [38400/50000]
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.378132
#
# Epoch 4
# -------------------------------
# loss: 0.035327  [    0/50000]
# loss: 0.105172  [12800/50000]
# loss: 0.040389  [25600/50000]
# loss: 0.043085  [38400/50000]
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.375416
#
# Epoch 5
# -------------------------------
# loss: 0.068892  [    0/50000]
# loss: 0.063093  [12800/50000]
# loss: 0.054713  [25600/50000]
# loss: 0.030431  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.372588
#
# Epoch 6
# -------------------------------
# loss: 0.021950  [    0/50000]
# loss: 0.028239  [12800/50000]
# loss: 0.038539  [25600/50000]
# loss: 0.035137  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.373142
#
# Epoch 7
# -------------------------------
# loss: 0.037423  [    0/50000]
# loss: 0.032742  [12800/50000]
# loss: 0.078561  [25600/50000]
# loss: 0.048637  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.379360
#
# Epoch 8
# -------------------------------
# loss: 0.054912  [    0/50000]
# loss: 0.061041  [12800/50000]
# loss: 0.044292  [25600/50000]
# loss: 0.050139  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.387322
#
# Epoch 9
# -------------------------------
# loss: 0.065240  [    0/50000]
# loss: 0.044596  [12800/50000]
# loss: 0.031219  [25600/50000]
# loss: 0.054235  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.384084
#
# Epoch 10
# -------------------------------
# loss: 0.020765  [    0/50000]
# loss: 0.051383  [12800/50000]
# loss: 0.024333  [25600/50000]
# loss: 0.071942  [38400/50000]
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.375698
#
# Epoch 11
# -------------------------------
# loss: 0.032821  [    0/50000]
# loss: 0.027973  [12800/50000]
# loss: 0.028440  [25600/50000]
# loss: 0.057996  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.379870
#
# Epoch 12
# -------------------------------
# loss: 0.070520  [    0/50000]
# loss: 0.024170  [12800/50000]
# loss: 0.025818  [25600/50000]
# loss: 0.021156  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.377983
#
# Epoch 13
# -------------------------------
# loss: 0.062093  [    0/50000]
# loss: 0.065560  [12800/50000]
# loss: 0.040449  [25600/50000]
# loss: 0.092615  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.377821
#
# Epoch 14
# -------------------------------
# loss: 0.033143  [    0/50000]
# loss: 0.047613  [12800/50000]
# loss: 0.065824  [25600/50000]
# loss: 0.058588  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.381016
#
# Epoch 15
# -------------------------------
# loss: 0.034740  [    0/50000]
# loss: 0.024279  [12800/50000]
# loss: 0.021774  [25600/50000]
# loss: 0.012716  [38400/50000]
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.381206
#
# Training routine finished for model: 2
# Epoch 1
# -------------------------------
# loss: 0.250297  [    0/50000]
# loss: 0.255694  [12800/50000]
# loss: 0.146451  [25600/50000]
# loss: 0.223256  [38400/50000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.391672
#
# Epoch 2
# -------------------------------
# loss: 0.308184  [    0/50000]
# loss: 0.224050  [12800/50000]
# loss: 0.295349  [25600/50000]
# loss: 0.206293  [38400/50000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.392898
#
# Epoch 3
# -------------------------------
# loss: 0.193782  [    0/50000]
# loss: 0.310738  [12800/50000]
# loss: 0.274873  [25600/50000]
# loss: 0.180794  [38400/50000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.387482
#
# Epoch 4
# -------------------------------
# loss: 0.267736  [    0/50000]
# loss: 0.231331  [12800/50000]
# loss: 0.329749  [25600/50000]
# loss: 0.244118  [38400/50000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.393043
#
# Epoch 5
# -------------------------------
# loss: 0.139225  [    0/50000]
# loss: 0.247391  [12800/50000]
# loss: 0.279840  [25600/50000]
# loss: 0.145089  [38400/50000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.393057
#
# Epoch 6
# -------------------------------
# loss: 0.139617  [    0/50000]
# loss: 0.203979  [12800/50000]
# loss: 0.189182  [25600/50000]
# loss: 0.277335  [38400/50000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.389618
#
# Epoch 7
# -------------------------------
# loss: 0.206581  [    0/50000]
# loss: 0.134141  [12800/50000]
# loss: 0.205532  [25600/50000]
# loss: 0.174872  [38400/50000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.386930
#
# Epoch 8
# -------------------------------
# loss: 0.288351  [    0/50000]
# loss: 0.222342  [12800/50000]
# loss: 0.221576  [25600/50000]
# loss: 0.200380  [38400/50000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.383594
#
# Epoch 9
# -------------------------------
# loss: 0.229456  [    0/50000]
# loss: 0.153691  [12800/50000]
# loss: 0.149066  [25600/50000]
# loss: 0.327309  [38400/50000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.390013
#
# Epoch 10
# -------------------------------
# loss: 0.164870  [    0/50000]
# loss: 0.195741  [12800/50000]
# loss: 0.191289  [25600/50000]
# loss: 0.254270  [38400/50000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.379990
#
# Epoch 11
# -------------------------------
# loss: 0.218719  [    0/50000]
# loss: 0.219342  [12800/50000]
# loss: 0.155491  [25600/50000]
# loss: 0.223566  [38400/50000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.381221
#
# Epoch 12
# -------------------------------
# loss: 0.240221  [    0/50000]
# loss: 0.210090  [12800/50000]
# loss: 0.297389  [25600/50000]
# loss: 0.217208  [38400/50000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.385724
#
# Epoch 13
# -------------------------------
# loss: 0.093806  [    0/50000]
# loss: 0.203311  [12800/50000]
# loss: 0.180313  [25600/50000]
# loss: 0.139778  [38400/50000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.380452
#
# Epoch 14
# -------------------------------
# loss: 0.337461  [    0/50000]
# loss: 0.192119  [12800/50000]
# loss: 0.388181  [25600/50000]
# loss: 0.138888  [38400/50000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.378867
#
# Epoch 15
# -------------------------------
# loss: 0.235109  [    0/50000]
# loss: 0.347089  [12800/50000]
# loss: 0.197043  [25600/50000]
# loss: 0.310210  [38400/50000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.379460
#
# Training routine finished for model: 3

# %%
file_models = [os.path.join(os.getcwd(),"CIFAR_m"+str(n+1)+".pth") for n in range(n_models)]

models = [FixupWideResNet(16, 4, 10, dropRate=0.3).to(device) for _ in range(n_models)]

train_dataloader, test_dataloader = get_cifar10_loaders()

for file, model in zip(file_models,models):
    model.load_state_dict(torch.load(file))
    model.eval()

LLA_D = []
LLA_K = []

for model in models:
### Laplace Approximation Diagonal
    la = Laplace(model, 'classification',
                subset_of_weights='last_layer',
                hessian_structure='diag')
        
    la.fit(train_dataloader)
    la.optimize_prior_precision(method='marglik',
                pred_type = "glm",
                link_approx = "probit",
                n_samples = 100)
    LLA_D.append(la)

### Laplace Approximation Kronocker Factor...
    la = Laplace(model, 'classification',
                subset_of_weights='last_layer',
                hessian_structure='kron')
        
    la.fit(train_dataloader)
    la.optimize_prior_precision(method='marglik',
                pred_type = "glm",
                link_approx = "probit",
                n_samples = 100)
    LLA_K.append(la)

# %%
# Einsum networks
from src.EinsumNetwork import Graph, EinsumNetwork
import src.utils


num_var = 10

exponential_family = EinsumNetwork.NormalArray
#exponential_family_args = {'min_var': 1e-6, 'max_var': 0.1}

#classes = [7]
K = 3

structure = 'binary-trees'

# 'binary-trees'
depth = 2
num_repetitions = 2

num_epochs = 5
batch_size = 100
online_em_frequency = 1
online_em_stepsize = 0.05


args = EinsumNetwork.Args(
        num_var=num_var,
        num_dims=1,
        num_classes=1,
        num_sums=K,
        num_input_distributions=K,
        exponential_family=exponential_family,
        online_em_frequency=online_em_frequency,
        online_em_stepsize=online_em_stepsize)

# %%
graph = Graph.random_binary_trees(num_var=num_var, depth=depth, num_repetitions=num_repetitions)

_, msg = Graph.check_graph(graph)

ly = torch.ones((3,3))/n_models**2

ly1 = ly.unsqueeze(2).repeat(1,1,3).unsqueeze(3).repeat(1,1,1,4)

ly2 = ly.unsqueeze(2).unsqueeze(3).repeat(1,1,1,2)

ly3 = torch.ones(2)/2

ly3 = ly3[None,None,:]

# %%
einet = EinsumNetwork.EinsumNetwork(graph, args)
einet.initialize({1:ly1, 2:ly2, 3:ly3})
#einet.initialize()
einet.to(device)
# Out:
# EinsumNetwork(
#   (einet_layers): ModuleList(
#     (0): FactorizedLeafLayer(
#       (ef_array): NormalArray()
#     )
#     (1): EinsumLayer()
#     (2): EinsumLayer()
#     (3): EinsumMixingLayer()
#   )
# )

# %%
def dis_params(test_dataloader):
    HMoLA_m = {}

    for nm in range(n_models):
        mv = []

        for x,y in test_dataloader:
            x = x.to(device)

            mv.append(torch.cat ((LLA_D[nm]._glm_predictive_distribution(x)[0].unsqueeze(-1),
                                torch.diagonal(LLA_D[nm]._glm_predictive_distribution(x)[1],dim1=2).unsqueeze(-1)),dim =-1))

        HMoLA_m[str(nm)] = torch.cat(mv,dim=0)
    
    return HMoLA_m

# %%
from tqdm import tqdm

def HMoLA_probs(HMoLA_m):
    
    prob = []

    for nd in tqdm(range(HMoLA_m["1"].shape[0])):

        einet.einet_layers[0].ef_array.params = torch.nn.Parameter(
        torch.cat(( HMoLA_m["0"][nd][:,None,None,:],
                    HMoLA_m["1"][nd][:,None,None,:],
                    HMoLA_m["2"][nd][:,None,None,:],
                    ), dim=1).repeat(1,1,2,1))

        samples = einet.sample(100)

        mu_pp = samples.mean(axis=0)
        var_pp = torch.diag(torch.cov(samples.T))

        kappa = 1 / torch.sqrt(1. + np.pi / 8 *var_pp )

        prob.append(torch.softmax(mu_pp * kappa, dim=-1))

    return torch.column_stack(prob).T

# %%
train_dataloader, test_dataloader = get_cifar10_loaders()

# %%
for sv in range(1,6):

    if sv == 0:
        test_dataloader
    else:
        test_dataloader = load_corrupted_cifar10(str(sv),corrupted_images_severity,corrupted_images_labels)

    HMoLA_m = dis_params(test_dataloader)

    all_y_HMoLA = HMoLA_probs(HMoLA_m)
    
    all_y_true = list()

    for (X,y) in test_dataloader:

        X , y = X.to(device), y.to(device)

        all_y_true.append(y.cpu())

    all_y_true = torch.cat(all_y_true, dim=0)

    ECE_["HMoLA"][str(sv)] = get_calib(all_y_HMoLA,all_y_true)
    BRI_["HMoLA"][str(sv)] = get_brier_score(all_y_HMoLA.cpu(),all_y_true)
    NLL_["HMoLA"][str(sv)] = loss_fn(all_y_HMoLA.cpu().log(), all_y_true).item()
# Out:
# 100%|██████████| 10000/10000 [16:07<00:00, 10.34it/s]
# 100%|██████████| 10000/10000 [12:22<00:00, 13.47it/s]
# 100%|██████████| 10000/10000 [29:25<00:00,  5.66it/s]
# 100%|██████████| 10000/10000 [17:31<00:00,  9.51it/s]
# 100%|██████████| 10000/10000 [17:14<00:00,  9.67it/s]

# %%
ECE_["HMoLA"][str(0)] = (0.034267917,0.963993)
BRI_["HMoLA"][str(0)] = 0.146537134
NLL_["HMoLA"][str(0)] = 0.309756965

# %%
ECE_["HMoLA"]
# Out:
# {'1': (0.02493663560034359, 0.7573714107275009),
#  '2': (0.08629657197676253, 0.26692575216293335),
#  '3': (0.053471655662308076, 0.8014190047979355),
#  '4': (0.06584210712711473, 0.24166233837604523),
#  '5': (0.09746110438631722, 0.27767153084278107),
#  '0': (0.034267917, 0.963993)}

# %%
for sv in range(0,6):

    if sv == 0:
        test_dataloader
    else:
        test_dataloader = load_corrupted_cifar10(str(sv),corrupted_images_severity,corrupted_images_labels)

    all_y_true = list()
    all_y_prob_D = list()
    all_y_prob_K = list()
    all_y_prob_MAP = list()
    all_y_prob_SWA = list()


    for (X,y) in test_dataloader:

        X , y = X.to(device), y.to(device)
        
        y_pred_MAP = mixture_model_pred(models, X, pi,True)

        y_pred_D = mixture_model_pred(LLA_D, X, pi)
        y_pred_K = mixture_model_pred(LLA_K, X, pi)
        y_pred_SWA = mixture_model_pred(SWAG_models, X, pi,True)

        all_y_true.append(y.cpu())

        all_y_prob_MAP.append(y_pred_MAP.cpu().detach())
        all_y_prob_D.append(y_pred_D.cpu())
        all_y_prob_K.append(y_pred_K.cpu())
        all_y_prob_SWA.append(y_pred_SWA.cpu().detach())

    all_y_prob_MAP = torch.cat(all_y_prob_MAP, dim=0)
    all_y_prob_SWA = torch.cat(all_y_prob_SWA, dim=0)

    all_y_prob_D = torch.cat(all_y_prob_D, dim=0)
    all_y_prob_K = torch.cat(all_y_prob_K, dim=0)

    all_y_true = torch.cat(all_y_true, dim=0)

    ECE_["Diag"][str(sv)] = get_calib(all_y_prob_D,all_y_true)
    ECE_["Kron"][str(sv)] = get_calib(all_y_prob_K,all_y_true)
    ECE_["MAP"][str(sv)] = get_calib(all_y_prob_MAP,all_y_true)
    ECE_["SWA"][str(sv)] = get_calib(all_y_prob_SWA,all_y_true)

    BRI_["Diag"][str(sv)] = get_brier_score(all_y_prob_D,all_y_true)
    BRI_["Kron"][str(sv)] = get_brier_score(all_y_prob_K,all_y_true)
    BRI_["MAP"][str(sv)] = get_brier_score(all_y_prob_MAP,all_y_true)
    BRI_["SWA"][str(sv)] = get_brier_score(all_y_prob_SWA,all_y_true)


    NLL_["Diag"][str(sv)] = loss_fn(all_y_prob_D.log(), all_y_true).item()
    NLL_["Kron"][str(sv)] = loss_fn(all_y_prob_K.log(), all_y_true).item()
    NLL_["MAP"][str(sv)] = loss_fn(all_y_prob_MAP.log(), all_y_true).item()
    NLL_["SWA"][str(sv)] = loss_fn(all_y_prob_SWA.log(), all_y_true).item()

# %%
ECE_["HMoLA"] = {'0': (0.034267917, 0.963993),
    '1': (0.02493663560034359, 0.7573714107275009),
 '2': (0.08629657197676253, 0.26692575216293335),
 '3': (0.053471655662308076, 0.8014190047979355),
 '4': (0.06584210712711473, 0.24166233837604523),
 '5': (0.09746110438631722, 0.27767153084278107),
 }

# %%
BRI_["HMoLA"] = {'0': 0.146537134,
    '1': 0.23321689665317535,
 '2': 0.41199198365211487,
 '3': 0.35234570503234863,
 '4': 0.3922552466392517,
 '5': 0.45955488085746765
 }

# %%
NLL_["HMoLA"] = {'0': 0.309756965,
    '1': 0.4673088490962982,
 '2': 0.8725464940071106,
 '3': 0.7298708558082581,
 '4': 0.8192363977432251,
 '5': 0.9951347708702087
 }

# %%
ECE_D = pd.DataFrame.from_dict(ECE_["Diag"]).T
ECE_K = pd.DataFrame.from_dict(ECE_["Kron"]).T
ECE_MAP = pd.DataFrame.from_dict(ECE_["MAP"]).T
ECE_SWA = pd.DataFrame.from_dict(ECE_["SWA"]).T
ECE_HMoLA = pd.DataFrame.from_dict(ECE_["HMoLA"]).T

BRI_D = pd.DataFrame.from_dict(BRI_["Diag"],orient='index')
BRI_K = pd.DataFrame.from_dict(BRI_["Kron"],orient='index')
BRI_MAP = pd.DataFrame.from_dict(BRI_["MAP"],orient='index')
BRI_SWA = pd.DataFrame.from_dict(BRI_["SWA"],orient='index')
BRI_HMoLA = pd.DataFrame.from_dict(BRI_["HMoLA"],orient='index')

NLL_D = pd.DataFrame.from_dict(NLL_["Diag"],orient='index')
NLL_K = pd.DataFrame.from_dict(NLL_["Kron"],orient='index')
NLL_MAP = pd.DataFrame.from_dict(NLL_["MAP"],orient='index')
NLL_SWA = pd.DataFrame.from_dict(NLL_["SWA"],orient='index')
NLL_HMoLA = pd.DataFrame.from_dict(NLL_["HMoLA"],orient='index')

# %%
fig, axs = plt.subplots(1, 3, figsize=(22, 4))

fig.suptitle('Gaussian Noise Corruption', fontsize=16,color="b")

axs[0].plot(ECE_MAP[0],'-o',label = "Ensemble MAP", color = "navy")
axs[0].plot(ECE_D[0],'-o',label = "Diagonal MoLA", color = "crimson")
axs[0].plot(ECE_K[0],'-o',label = "KFAC MoLA", color = "teal")
axs[0].plot(ECE_SWA[0],'-o',label = "MultiSWAG", color = "steelblue")
axs[0].plot(ECE_HMoLA[0],'-o',label = "HMoLA", color = "black")


axs[0].set_xlabel(r"Level of Severity")
axs[0].set_ylabel(r"ECE")

axs[0].legend(frameon=False)
axs[0].grid(True,linestyle = '--', linewidth = 0.5)


axs[1].plot(BRI_MAP,'-o',label = "Ensemble MAP", color = "navy")
axs[1].plot(BRI_D,'-o',label = "Diagonal MoLA", color = "crimson")
axs[1].plot(BRI_K,'-o',label = "KFAC MoLA", color = "teal")
axs[1].plot(BRI_SWA,'-o',label = "MultiSWAG", color = "steelblue")
axs[1].plot(BRI_HMoLA,'-o',label = "HMoLA", color = "black")

axs[1].set_xlabel(r"Level of Severity")
axs[1].set_ylabel(r"Brier Score")

#axs[1].legend(frameon=False)
axs[1].grid(True,linestyle = '--', linewidth = 0.5)



axs[2].plot(-NLL_MAP,'-o',label = "Ensemble MAP", color = "navy")
axs[2].plot(-NLL_D,'-o',label = "Diagonal MoLA", color = "crimson")
axs[2].plot(-NLL_K,'-o',label = "KFAC MoLA", color = "teal")
axs[2].plot(-NLL_SWA,'-o',label = "MultiSWAG", color = "steelblue")
axs[2].plot(-NLL_HMoLA,'-o',label = "HMoLA", color = "black")

axs[2].set_xlabel(r"Level of Severity")
axs[2].set_ylabel(r"Log-Likelihood")

#axs[1].legend(frameon=False)
axs[2].grid(True,linestyle = '--', linewidth = 0.5)
